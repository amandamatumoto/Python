# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Funções do Pandas

# %%
df = pd.read_csv('campeonato-brasileiro-full.csv')

# %%
df
# Out:
#         ID Rodada        Data Horário      Dia     Mandante      Visitante  \
# 0        1      1  29/07/2000   16h00   Sábado   Fluminense          Bahia
# 1        2      1  29/07/2000   16h00   Sábado        Vasco          Sport
# 2        3      1  29/07/2000   16h00   Sábado      Vitória      Palmeiras
# 3        4      1  30/07/2000   17h00  Domingo  Botafogo-RJ    Atlético-MG
# 4        5      1  30/07/2000   18h30  Domingo    Juventude       Flamengo
# ...    ...    ...         ...     ...      ...          ...            ...
# 8342  8343      3  13/06/2021   16:00  Domingo       grêmio   athletico-pr
# 8343  8344      3  13/06/2021   20:30  Domingo        bahia  internacional
# 8344  8345      3  13/06/2021   20:30  Domingo    fortaleza          sport
# 8345  8346      3  13/06/2021   20:30  Domingo   bragantino     fluminense
# 8346  8347      3  13/06/2021   20:30  Domingo  chapecoense          ceará
#
# ...

# %%
df.head(10) # mostra as 10 primeiras linhas da dataframe - degustação
# Out:
#    ID Rodada        Data Horário           Dia     Mandante     Visitante  \
# 0   1      1  29/07/2000   16h00        Sábado   Fluminense         Bahia
# 1   2      1  29/07/2000   16h00        Sábado        Vasco         Sport
# 2   3      1  29/07/2000   16h00        Sábado      Vitória     Palmeiras
# 3   4      1  30/07/2000   17h00       Domingo  Botafogo-RJ   Atlético-MG
# 4   5      1  30/07/2000   18h30       Domingo    Juventude      Flamengo
# 5   6      1  30/07/2000   16h00       Domingo      Guarani    Santa Cruz
# 6   7      1  30/07/2000   17h00       Domingo     Cruzeiro  Athlético-PR
# 7   8      1  30/07/2000   16h00       Domingo   América-MG          Gama
# 8   9      1  30/07/2000   18h30       Domingo        Goiás   Corinthians
# 9  10      2  02/08/2000   20h30  Quarta-feira     Coritiba         Sport
#
#        Vencedor           Arena  Mandante Placar  Visitante Placar  \
# 0    Fluminense        Maracanã                2                 0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8347 entries, 0 to 8346
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                8347 non-null   int64
#  1   Rodada            8347 non-null   object
#  2   Data              8347 non-null   object
#  3   Horário           7990 non-null   object
#  4   Dia               8347 non-null   object
#  5   Mandante          8347 non-null   object
#  6   Visitante         8347 non-null   object
#  7   Vencedor          8347 non-null   object
#  8   Arena             8347 non-null   object
#  9   Mandante Placar   8347 non-null   int64
#  10  Visitante Placar  8347 non-null   int64
#  11  Estado Mandante   8347 non-null   object
#  12  Estado Visitante  8347 non-null   object
#  13  Estado Vencedor   8347 non-null   object
# dtypes: int64(3), object(11)
# memory usage: 913.1+ KB

# %% [markdown]
# ### Qual foi a média de gols?

# %%
df['Mandante Placar'].mean()
# Out:
# 1.5873966694620822

# %%
df['Visitante Placar'].mean()
# Out:
# 1.0533125673894812

# %%
df['Total de Gols'] = df['Mandante Placar'] + df['Visitante Placar']

# %%
df.head()
# Out:
#    ID Rodada        Data Horário      Dia     Mandante    Visitante  \
# 0   1      1  29/07/2000   16h00   Sábado   Fluminense        Bahia
# 1   2      1  29/07/2000   16h00   Sábado        Vasco        Sport
# 2   3      1  29/07/2000   16h00   Sábado      Vitória    Palmeiras
# 3   4      1  30/07/2000   17h00  Domingo  Botafogo-RJ  Atlético-MG
# 4   5      1  30/07/2000   18h30  Domingo    Juventude     Flamengo
#
#      Vencedor           Arena  Mandante Placar  Visitante Placar  \
# 0  Fluminense        Maracanã                2                 0
# 1       Sport    São Januário                0                 2
# 2     Vitória        Barradão                4                 1
# 3           -    Caio Martins                0                 0
# 4           -  Alfredo Jaconi                1                 1
#
#   Estado Mandante Estado Visitante Estado Vencedor  Total de Gols
# 0              RJ               BA              RJ              2
# ...

# %%
df['Total de Gols'].mean()
# Out:
# 2.6407092368515634

# %% [markdown]
# ### Qual foi o time que mais venceu?

# %%
df['Vencedor'].value_counts().to_frame()
# Out:
#                Vencedor
# -                  2156
# São Paulo           366
# Santos              333
# Cruzeiro            322
# Grêmio              322
# ...                 ...
# fluminense            1
# palmeiras             1
# internacional         1
# INTERNACIONAL         1
# santos                1
#
# [71 rows x 1 columns]

# %% [markdown]
#  ## Limpando dados

# %%
df['Vencedor'] = df['Vencedor'].str.upper()

# %%
df['Vencedor'].value_counts().to_frame()
# Out:
#                  Vencedor
# -                    2156
# SÃO PAULO             366
# SANTOS                340
# CRUZEIRO              326
# INTERNACIONAL         324
# GRÊMIO                322
# FLAMENGO              322
# FLUMINENSE            311
# CORINTHIANS           310
# ATHLÉTICO-PR          308
# ATLÉTICO-MG           304
# PALMEIRAS             296
# BOTAFOGO-RJ           236
# VASCO                 230
# GOIÁS                 223
# CORITIBA              194
# VITÓRIA               152
# FIGUEIRENSE           151
# PONTE PRETA           150
# SPORT                 141
# BAHIA                 136
# PARANÁ                104
# SÃO CAETANO           103
# JUVENTUDE              96
# CHAPECOENSE            69
# FORTALEZA              64
# GUARANI                63
# PORTUGUESA             58
# AVAÍ                   57
# CEARÁ                  55
# NÁUTICO                54
# ATLÉTICO-GO            53
# CRICIÚMA               50
# PAYSANDU               50
# ...

# %% [markdown]
# ### Estado com maior número de vitórias

# %%
df['Estado Vencedor'].value_counts()
# Out:
# -     2156
# SP    1736
# RJ    1099
# RS     742
# MG     677
# PR     607
# SC     334
# GO     276
# PE     220
# ES     152
# BA     136
# CE     119
# PA      50
# DF      31
# AL       8
# RN       4
# Name: Estado Vencedor, dtype: int64

# %% [markdown]
# ### Ordenando valores de acordo com a coluna - sort_values

# %%
df.sort_values(by='Mandante Placar', ascending = False)
# Out:
#         ID Rodada        Data Horário           Dia       Mandante  \
# 1671  1672      6  16/05/2004   16h00       Domingo       Criciúma
# 2055  2056     38  27/10/2004   20h30  Quarta-feira     Fluminense
# 2557  2558     37  06/11/2005   16h00       Domingo    Corinthians
# 1122  1123      6  27/04/2003   16h00       Domingo          Goiás
# 1992  1993     33  28/09/2004   20h30   Terça-feira      São Paulo
# ...    ...    ...         ...     ...           ...            ...
# 2945  2946     33  05/11/2006   16h00       Domingo         Grêmio
# 2948  2949     33  05/11/2006   16h00       Domingo         Santos
# 6477  6478      6  05/06/2016   18:30       Domingo       Cruzeiro
# 2949  2950     34  08/11/2006   21h45  Quarta-feira  Internacional
# 8346  8347      3  13/06/2021   20:30       Domingo    chapecoense
#
#           Visitante       Vencedor                Arena  Mandante Placar  \
# 1671          Goiás       CRICIÚMA      Heriberto Hulse                7
# ...

# %% [markdown]
# # unique

# %%
df['Mandante'].unique()
# Out:
# array(['Fluminense', 'Vasco', 'Vitória', 'Botafogo-RJ', 'Juventude',
#        'Guarani', 'Cruzeiro', 'América-MG', 'Goiás', 'Coritiba', 'Bahia',
#        'Flamengo', 'Gama', 'Internacional', 'Ponte Preta', 'Santos',
#        'Palmeiras', 'Athlético-PR', 'Corinthians', 'Atlético-MG',
#        'Portuguesa', 'Grêmio', 'São Paulo', 'Santa Cruz', 'Sport',
#        'INTERNACIONAL', 'Paraná', 'REMO', 'São Caetano', 'MALUTROM',
#        'PALMEIRAS', 'BAHIA', 'CRUZEIRO', 'PONTE PRETA', 'FLUMINENSE',
#        'SPORT', 'VASCO', 'Botafogo-SP', 'Figueirense', 'Paysandu',
#        'SANTOS', 'CORINTHIANS', 'JUVENTUDE', 'Fortaleza', 'Criciúma',
#        'Brasiliense', 'América-RN', 'Náutico', 'Ipatinga', 'Avaí',
#        'Santo André', 'Barueri', 'FLAMENGO', 'Atlético-GO', 'Ceará',
#        'Grêmio Prudente', 'Chapecoense', 'Joinville', 'Botafogo-rj',
#        'CSA', 'Bragantino', 'Cuiabá', 'palmeiras', 'santos', 'flamengo',
#        'atlético-mg', 'grêmio', 'bahia', 'fortaleza', 'bragantino',
# ...

# %%
df['Mandante'] = df['Mandante'].str.upper()

# %%
df['Mandante'].unique()
# Out:
# array(['FLUMINENSE', 'VASCO', 'VITÓRIA', 'BOTAFOGO-RJ', 'JUVENTUDE',
#        'GUARANI', 'CRUZEIRO', 'AMÉRICA-MG', 'GOIÁS', 'CORITIBA', 'BAHIA',
#        'FLAMENGO', 'GAMA', 'INTERNACIONAL', 'PONTE PRETA', 'SANTOS',
#        'PALMEIRAS', 'ATHLÉTICO-PR', 'CORINTHIANS', 'ATLÉTICO-MG',
#        'PORTUGUESA', 'GRÊMIO', 'SÃO PAULO', 'SANTA CRUZ', 'SPORT',
#        'PARANÁ', 'REMO', 'SÃO CAETANO', 'MALUTROM', 'BOTAFOGO-SP',
#        'FIGUEIRENSE', 'PAYSANDU', 'FORTALEZA', 'CRICIÚMA', 'BRASILIENSE',
#        'AMÉRICA-RN', 'NÁUTICO', 'IPATINGA', 'AVAÍ', 'SANTO ANDRÉ',
#        'BARUERI', 'ATLÉTICO-GO', 'CEARÁ', 'GRÊMIO PRUDENTE',
#        'CHAPECOENSE', 'JOINVILLE', 'CSA', 'BRAGANTINO', 'CUIABÁ'],
#       dtype=object)

# %% [markdown]
# # nunique - número de valores únicos

# %%
df['Mandante'].nunique()
# Out:
# 49

# %%
df['Visitante'].nunique()
# Out:
# 82

# %%
df['Visitante'] = df['Visitante'].str.upper()

# %%
df['Visitante'].nunique()
# Out:
# 50

# %% [markdown]
# ### Qual foi a maior goleada de todos os tempos?

# %%
df[df['Mandante Placar'] == df['Mandante Placar'].max()]
# Out:
#         ID Rodada        Data Horário           Dia      Mandante  Visitante  \
# 357    358      2  05/08/2001   14h30       Domingo         VASCO    GUARANI
# 693    694     26  25/11/2001   16h00       Domingo         VASCO  SÃO PAULO
# 1122  1123      6  27/04/2003   16h00       Domingo         GOIÁS  JUVENTUDE
# 1671  1672      6  16/05/2004   16h00       Domingo      CRICIÚMA      GOIÁS
# 1992  1993     33  28/09/2004   20h30   Terça-feira     SÃO PAULO   PAYSANDU
# 2055  2056     38  27/10/2004   20h30  Quarta-feira    FLUMINENSE  JUVENTUDE
# 2309  2310     15  27/07/2005   21h45  Quarta-feira  ATHLÉTICO-PR      VASCO
# 2557  2558     37  06/11/2005   16h00       Domingo   CORINTHIANS     SANTOS
#
#           Vencedor                Arena  Mandante Placar  Visitante Placar  \
# 357          VASCO         São Januário                7                 1
# 693          VASCO         São Januário                7                 1
# ...

# %% [markdown]
# ### Qual time fez mais gols no campeonato brasileiro?

# %%
df.groupby('Mandante')

# %%
by_mandante = df.groupby('Mandante')

# %%
by_mandante['Mandante Placar'].sum()
# Out:
# Mandante
# AMÉRICA-MG         103
# AMÉRICA-RN          12
# ATHLÉTICO-PR       639
# ATLÉTICO-GO        121
# ATLÉTICO-MG        663
# AVAÍ               147
# BAHIA              305
# BARUERI             35
# BOTAFOGO-RJ        533
# BOTAFOGO-SP          9
# BRAGANTINO          39
# BRASILIENSE         26
# CEARÁ              119
# CHAPECOENSE        136
# CORINTHIANS        581
# CORITIBA           417
# CRICIÚMA           121
# CRUZEIRO           668
# CSA                 17
# CUIABÁ               2
# FIGUEIRENSE        325
# FLAMENGO           640
# FLUMINENSE         608
# FORTALEZA          160
# GAMA                53
# GOIÁS              521
# GRÊMIO             646
# GRÊMIO PRUDENTE     25
# GUARANI            131
# INTERNACIONAL      599
# IPATINGA            28
# JOINVILLE           19
# JUVENTUDE          211
# MALUTROM             0
# NÁUTICO            131
# PALMEIRAS          601
# PARANÁ             231
# PAYSANDU           159
# PONTE PRETA        346
# ...

# %%
by_mandante['Mandante Placar'].sum().sort_values(ascending=False)
# Out:
# Mandante
# SANTOS             739
# SÃO PAULO          692
# CRUZEIRO           668
# ATLÉTICO-MG        663
# GRÊMIO             646
# FLAMENGO           640
# ATHLÉTICO-PR       639
# FLUMINENSE         608
# PALMEIRAS          601
# INTERNACIONAL      599
# CORINTHIANS        581
# VASCO              535
# BOTAFOGO-RJ        533
# GOIÁS              521
# CORITIBA           417
# VITÓRIA            394
# PONTE PRETA        346
# FIGUEIRENSE        325
# SPORT              321
# BAHIA              305
# PARANÁ             231
# JUVENTUDE          211
# SÃO CAETANO        185
# FORTALEZA          160
# PAYSANDU           159
# PORTUGUESA         149
# AVAÍ               147
# CHAPECOENSE        136
# NÁUTICO            131
# GUARANI            131
# ATLÉTICO-GO        121
# CRICIÚMA           121
# CEARÁ              119
# AMÉRICA-MG         103
# SANTA CRUZ          78
# GAMA                53
# BRAGANTINO          39
# BARUERI             35
# SANTO ANDRÉ         29
# ...
